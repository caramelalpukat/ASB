# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_p='rul.jpg'
img=cv2.imread(img_p)
print(img.shape)
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
R,G,B=fix_img[:,:,0],fix_img[:,:,1],fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (4160, 2340, 3)
# [[[190 210 234]
#   [188 208 232]
#   [188 208 232]
#   ...
#   [192 208 233]
#   [192 208 233]
#   [193 209 234]]
#
#  [[189 209 233]
#   [188 208 232]
#   [188 208 232]
#   ...
#   [192 208 233]
#   [192 208 233]
#   [192 208 233]]
#
#  [[189 209 233]
#   [188 208 232]
#   [188 208 232]
#   ...
#   [193 209 234]
#   [193 209 234]
#   [193 209 234]]
#
#  ...
#
#  [[135 144 151]
#   [134 143 150]
#   [135 144 151]
#   ...
#   [139 147 149]
#   [139 147 149]
#   [138 146 148]]
#
#  [[137 146 153]
#   [135 144 151]
#   [136 145 152]
#   ...
#   [140 148 150]
#   [139 147 149]
#   [139 147 149]]
#
#  [[134 143 150]
#   [135 144 151]
#   [138 147 154]
#   ...
#   [139 147 149]
#   [139 147 149]
#   [138 146 148]]]

# %%
fix_img[:]=np.max(fix_img,axis=-1,keepdims=1)/2+np.min(fix_img,axis=-1,keepdims=1)/2

print(np.array(fix_img[:]))
plt.axis('off')
plt.imshow(fix_img[:])
plt.savefig('mode light',bbox_inches='tight')
# Out:
# [[[212 212 212]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [212 212 212]
#   [212 212 212]
#   [213 213 213]]
#
#  [[211 211 211]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [212 212 212]
#   [212 212 212]
#   [212 212 212]]
#
#  [[211 211 211]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [213 213 213]
#   [213 213 213]
#   [213 213 213]]
#
#  ...
#
#  [[143 143 143]
#   [142 142 142]
#   [143 143 143]
#   ...
#   [144 144 144]
#   [144 144 144]
#   [143 143 143]]
#
#  [[145 145 145]
#   [143 143 143]
#   [144 144 144]
#   ...
#   [145 145 145]
#   [144 144 144]
#   [144 144 144]]
#
#  [[142 142 142]
#   [143 143 143]
#   [146 146 146]
#   ...
#   [144 144 144]
#   [144 144 144]
#   [143 143 143]]]

# %%
gray_img=np.mean(fix_img,axis=-1)
print(np.array(gray_img))
plt.axis('off')
plt.imshow(gray_img,cmap='gray')
plt.savefig('metode Average',bbox_inches='tight')
# Out:
# [[211.33333333 209.33333333 209.33333333 ... 211.         211.
#   212.        ]
#  [210.33333333 209.33333333 209.33333333 ... 211.         211.
#   211.        ]
#  [210.33333333 209.33333333 209.33333333 ... 212.         212.
#   212.        ]
#  ...
#  [143.33333333 142.33333333 143.33333333 ... 145.         145.
#   144.        ]
#  [145.33333333 143.33333333 144.33333333 ... 146.         145.
#   145.        ]
#  [142.33333333 143.33333333 146.33333333 ... 145.         145.
#   144.        ]]

# %%
lumi_img=(0.2126*R)+(0.7152*G)+(0.0722*B)
print(np.array(lumi_img))
lumi_img_transposed = np.transpose(lumi_img)

# Print the transposed luminosity matrix
print(np.array(lumi_img_transposed))
plt.axis('off')
plt.imshow(lumi_img,cmap='gray')
plt.savefig('metode luminosity',bbox_inches='tight')
# Out:
# [[207.4808 205.4808 205.4808 ... 206.4034 206.4034 207.4034]
#  [206.4808 205.4808 205.4808 ... 206.4034 206.4034 206.4034]
#  [206.4808 205.4808 205.4808 ... 207.4034 207.4034 207.4034]
#  ...
#  [142.592  141.592  142.592  ... 145.4436 145.4436 144.4436]
#  [144.592  142.592  143.592  ... 146.4436 145.4436 145.4436]
#  [141.592  142.592  145.592  ... 145.4436 145.4436 144.4436]]
# [[207.4808 206.4808 206.4808 ... 142.592  144.592  141.592 ]
#  [205.4808 205.4808 205.4808 ... 141.592  142.592  142.592 ]
#  [205.4808 205.4808 205.4808 ... 142.592  143.592  145.592 ]
#  ...
#  [206.4034 206.4034 207.4034 ... 145.4436 146.4436 145.4436]
#  [206.4034 206.4034 207.4034 ... 145.4436 145.4436 145.4436]
#  [207.4034 206.4034 207.4034 ... 144.4436 145.4436 144.4436]]

# %%
wav_img=(0.299*R)+(0.587*G)+(0.114*B)
print(np.array(wav_img))
plt.axis('off')
plt.imshow(wav_img,cmap='gray')
plt.savefig('Metode Weight Average',bbox_inches='tight')
# Out:
# [[206.756 204.756 204.756 ... 206.066 206.066 207.066]
#  [205.756 204.756 204.756 ... 206.066 206.066 206.066]
#  [205.756 204.756 204.756 ... 207.066 207.066 207.066]
#  ...
#  [142.107 141.107 142.107 ... 144.836 144.836 143.836]
#  [144.107 142.107 143.107 ... 145.836 144.836 144.836]
#  [141.107 142.107 145.107 ... 144.836 144.836 143.836]]
